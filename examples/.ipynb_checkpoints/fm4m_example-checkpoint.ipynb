# %% [markdown]
# ### Import libraries

# %%
import sys
sys.path.append("../models")
sys.path.append("../")

# %%
import models.fm4m as fm4m
import pandas as pd
import numpy as np
from sklearn.svm import SVR
from sklearn.compose import TransformedTargetRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Load data

# %%
train_df  = pd.read_csv(f"../data/bace/train.csv")
test_df  = pd.read_csv(f"../data/bace/test.csv")

# %%
train_df.head()
# Out:
#                                               smiles     CID  Class  \
# 0  O1CC[C@@H](NC(=O)[C@@H](Cc2cc3cc(ccc3nc2N)-c2c...  BACE_1      1
# 1  S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...  BACE_3      1
# 2  S1(=O)(=O)N(c2cc(cc3c2n(cc3CC)CC1)C(=O)N[C@H](...  BACE_5      1
# 3  S(=O)(=O)(CCCCC)C[C@@H](NC(=O)c1cccnc1)C(=O)N[...  BACE_7      1
# 4  O1c2c(cc(cc2)CC)[C@@H]([NH2+]C[C@@H](O)[C@H]2N...  BACE_9      1
#
#    Unnamed: 3     pIC50         MW   AlogP  HBA  HBD  RB  ...  PEOE6 (PEOE6)  \
# 0         NaN  9.154901  431.56979  4.4014    3    2   5  ...      53.205711
# 1         NaN  8.698970  591.74091  2.5499    4    3  11  ...      70.365707
# 2         NaN  8.698970  629.71283  3.5086    3    3  11  ...      78.945702
# 3         NaN  8.698970  645.78009  3.1973    5    4  18  ...      63.830162
# 4         NaN  8.602060  556.71503  4.7010    4    3   5  ...      53.205711
#
#    PEOE7 (PEOE7)  PEOE8 (PEOE8)  PEOE9 (PEOE9)  PEOE10 (PEOE10)  \
# ...

# %%
xtrain = list(train_df["smiles"].values)
ytrain = list(train_df["Class"].values)

xtest = list(test_df["smiles"].values) 
ytest = list(test_df["Class"].values)

# %% [markdown]
# ### List of available models

# %% [markdown]
# #### Base Models

# %%
fm4m.avail_models()
# Out:
#     Model Name                                       Description
# 0      SMI-TED                SMILES based encoder decoder model
# 1  SELFIES-TED      BART model for string based SELFIES modality
# 2    Molformer  MolFormer model for string based SMILES modality
# 3      MHG-GED                        Molecular hypergraph model

# %% [markdown]
# #### Downstream Models

# %%
fm4m.avail_downstream_models()
# Out:
#                 Name      Task Type
# 0      XGBClassifier  Classfication
# 1  DefaultClassifier  Classfication
# 2                SVR     Regression
# 3       Kernel Ridge     Regression
# 4  Linear Regression     Regression
# 5   DefaultRegressor     Regression

# %% [markdown]
# ### Example of single-modal model usage

# %% [markdown]
# #### Model Type : SELFIES-TED

# %%
fm4m.single_modal(model="SELFIES-TED", x_train=xtrain, y_train=ytrain, x_test=xtest, y_test=ytest, downstream_model="DefaultClassifier")
# Out:
# SELFIES-TED
# /Users/indrapriyadarsinis/.pyenv/versions/3.10.8/envs/amd/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ...
# Map:   0%|          | 0/152 [00:00<?, ? examples/s]
#  Calculating ROC AUC Score ...
# ROC-AUC Score: 0.8520
# Generating latent plots
# Generating latent plots : Done
# ('ROC-AUC Score: 0.8520',
#  0.8519809244314013,
#  array([0.        , 0.        , 0.0106383 , 0.0106383 , 0.0212766 ,
#         0.0212766 , 0.03191489, 0.03191489, 0.04255319, 0.04255319,
#         0.05319149, 0.05319149, 0.06382979, 0.06382979, 0.07446809,
#         0.07446809, 0.10638298, 0.10638298, 0.11702128, 0.11702128,
# ...

# %% [markdown]
# #### Model Type : MHG-GNN

# %%
fm4m.single_modal(model="MHG-GED", x_train=xtrain, y_train=ytrain, x_test=xtest, y_test=ytest, downstream_model="DefaultClassifier")
# Out:
# MHG-GED
# MHG Model Loaded
#  Calculating ROC AUC Score ...
# ROC-AUC Score: 0.8690
# Generating latent plots
# Generating latent plots : Done
# ('ROC-AUC Score: 0.8690',
#  0.8690388848129127,
#  array([0.        , 0.        , 0.        , 0.0212766 , 0.0212766 ,
#         0.03191489, 0.03191489, 0.06382979, 0.06382979, 0.08510638,
#         0.08510638, 0.09574468, 0.09574468, 0.13829787, 0.13829787,
#         0.14893617, 0.14893617, 0.15957447, 0.15957447, 0.17021277,
#         0.17021277, 0.18085106, 0.18085106, 0.19148936, 0.19148936,
#         0.24468085, 0.24468085, 0.28723404, 0.28723404, 0.29787234,
#         0.29787234, 0.31914894, 0.31914894, 0.32978723, 0.32978723,
#         0.38297872, 0.38297872, 0.39361702, 0.39361702, 0.89361702,
#         0.89361702, 1.        ]),
#  array([0.        , 0.01724138, 0.10344828, 0.10344828, 0.32758621,
#         0.32758621, 0.4137931 , 0.4137931 , 0.43103448, 0.43103448,
# ...

# %% [markdown]
# #### Model Type : SMI-TED

# %%
fm4m.single_modal(model="SMI-TED", x_train=xtrain, y_train=ytrain, x_test=xtest, y_test=ytest, downstream_model="DefaultClassifier")
# Out:
# SMI-TED
# Random Seed: 12345
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Vocab size: 2393
# [INFERENCE MODE - smi-ted-Light]
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.15s/it]
#  Calculating ROC AUC Score ...
# ROC-AUC Score: 0.8267
# Generating latent plots
# Generating latent plots : Done
# ('ROC-AUC Score: 0.8267',
#  0.8266691122523844,
#  array([0.        , 0.        , 0.        , 0.0106383 , 0.0106383 ,
#         0.0212766 , 0.0212766 , 0.03191489, 0.03191489, 0.04255319,
#         0.04255319, 0.05319149, 0.05319149, 0.06382979, 0.06382979,
# ...

# %% [markdown]
# ### Example of multi-modal model usage

# %%
fm4m.multi_modal(model_list=["SELFIES-TED","MHG-GED","SMI-TED"], x_train=xtrain, y_train=ytrain, x_test=xtest, y_test=ytest, downstream_model="DefaultClassifier")
# Out:
# /Users/indrapriyadarsinis/.pyenv/versions/3.10.8/envs/amd/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ...
# Map:   0%|          | 0/152 [00:00<?, ? examples/s]
# MHG Model Loaded
# Random Seed: 12345
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Using Rotation Embedding
# Vocab size: 2393
# [INFERENCE MODE - smi-ted-Light]
# ...
